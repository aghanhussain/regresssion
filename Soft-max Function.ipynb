# %%
import matplotlib.pyplot as plt
import numpy as np

scores = np.array([3.0, 1.0, 0.2])
# Defining Softmax Function

def softmax(x):
    probability=[]
    
    for i in x:
        p=np.exp(i)/sum(np.exp(x))
        probability.append(p)
    return probability
    


print(softmax(scores/10))

# sum of all probabiliteis is always equal to 1.
print(sum(softmax(scores)))

# Graph of Softmax Values 
x = np.arange(-2.0, 6.0, 0.1)
scores = np.vstack([x, np.ones_like(x), 0.2 * np.ones_like(x)])

plt.plot(x, np.transpose(softmax(scores)) , linewidth=2)
plt.show()
# Out:
# [0.38842275004597271, 0.31801365065775999, 0.2935635992962673]
# 1.0
